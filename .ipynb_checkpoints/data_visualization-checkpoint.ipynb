# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
dfG = pd.read_csv('data_lakehouse/gold/starG.csv').drop(columns=['SpT', 'created_date','last_updated_date'])
dfG
# Out:
#       recno Class  SubClass Luminosity Class   Teff1  logg1   FeH1    Vmag  \
# 0         1     F         0              NaN  7080.0  4.178 -0.148  10.907
# 1         2     A         6               IV  7404.0  4.069  0.031  10.410
# 2         3     F         0              NaN  7330.0  4.102 -0.133  14.155
# 3         4     A         7                V  7218.0  4.182 -0.300  13.497
# 4        10     F         0              NaN  7516.0  3.850  0.232   9.543
# ...     ...   ...       ...              ...     ...    ...    ...     ...
# 7978  21626     F         0              NaN  7234.0  4.084 -0.219  13.274
# 7979  21628     F         0              NaN  7145.0  4.114 -0.275  14.575
# 7980  21629     F         0              NaN  7348.0  4.050 -0.132  15.263
# 7981  21631     F         0              NaN  7357.0  3.913  0.236  13.035
# 7982  21635     F         0              NaN  7393.0  4.038 -0.147  12.290
#
#       e_Vmag   Teff2   logg2   FeH2    Rad   Mass       Lum Ca_K H_lines  \
# 0      0.008  7078.0  3.4750 -0.151  3.797  1.570  32.60238   A7      F3
# 1      0.005  7405.0  4.2137  0.032  1.684  1.691   7.68098   A7      F0
# 2      0.126  7331.0  4.3672 -0.133  1.398  1.660   5.08514   A7      F1
# 3      0.080  7220.0  4.2537 -0.301  1.574  1.620   6.06511   A5      A4
# 4      0.003  7530.0  3.8710  0.235  2.534  1.740  18.59625   A6      A8
# ...      ...     ...     ...    ...    ...    ...       ...  ...     ...
# 7978   0.092  7241.0  4.1929 -0.216  1.693  1.630   7.10133   A6      F2
# 7979   0.137  7153.0  4.3207 -0.273  1.448  1.600   4.94327   A6      F1
# 7980   0.057  7350.0  4.1327 -0.133  1.837  1.670   8.86950   A7      A9
# 7981   0.103  7358.0  3.7906  0.235  2.723  1.670  19.58132   A7      F0
# 7982   0.069  7394.0  4.2558 -0.145  1.603  1.690   6.92185   A5      A7
#
#      Metal_lines
# 0             F2
# 1             F0
# 2             F0
# 3             A9
# 4             F0
# ...          ...
# 7978          F1
# 7979          F0
# 7980          F1
# 7981          F0
# 7982          A9
#
# [7983 rows x 18 columns]

# %%
print( 'Number of Class: ' + str(dfG['Class'].nunique() ) )
print( 'Number of Sub Classes: ' + str(dfG['SubClass'].nunique() ) )
print( 'Number of Luminosity Classes: ' + str(dfG['Luminosity Class'].nunique() ) )
#print( 'Number of SpT: ' + str(dfG['SpT'].nunique() ) )
# Out:
# Number of Class: 2
# Number of Sub Classes: 9
# Number of Luminosity Classes: 3

# %%
print( 'Different Classes:' + str( dfG['Class'].unique() ) )
print( 'Different SubClasses:' + str( dfG['SubClass'].unique() ) )
print( 'Different Luminosity Classes:' + str( dfG['Luminosity Class'].unique() ) )
# Out:
# Different Classes:['F' 'A']
# Different SubClasses:[0 6 7 5 2 3 9 8 1]
# Different Luminosity Classes:[nan 'IV' 'V' 'II']

# %%
# categories = np.unique(dfF['Ca_K'])
# na_list = []
# for category in categories:
#     cat_list = []
#     counter = 1
#     for j in range(len(categories)):
#         #print((dfF['Teff1'][j] ))
#         #print(type(dfF['Teff1'][j] ))
#         if dfF['Ca_K'][j] == category:
#             if dfF['Teff1'].isnull()[j] == np.True_:
#                 counter = counter + 1
#     na_list.append([category,counter])
# print(na_list)
# #dfF

# %%
# Compute covariance matrix
cov_matrix = np.sqrt( np.abs(dfG.select_dtypes(include=['number']).drop(['recno','SubClass'], axis=1).cov()) )
cov_matrix
# Out:
#              Teff1     logg1      FeH1      Vmag    e_Vmag       Teff2  \
# Teff1   343.744705  3.230971  4.903739  5.715161  1.068011  342.820484
# logg1     3.230971  0.135194  0.141789  0.170883  0.035452    3.293874
# FeH1      4.903739  0.141789  0.250396  0.275573  0.056724    4.882080
# Vmag      5.715161  0.170883  0.275573  1.279332  0.244563    5.802146
# e_Vmag    1.068011  0.035452  0.056724  0.244563  0.090314    1.068047
# Teff2   342.820484  3.293874  4.882080  5.802146  1.068047  348.986952
# logg2     2.646298  0.096799  0.093454  0.265913  0.051941    2.789345
# FeH2      4.856059  0.142401  0.249416  0.275419  0.056784    4.935901
# Rad       3.327704  0.161107  0.160110  0.392158  0.077809    3.170948
# Mass      6.802571  0.065123  0.096472  0.114950  0.021103    6.926419
# Lum      30.664889  0.628613  0.627286  1.238871  0.256724   30.814898
#
#            logg2      FeH2       Rad      Mass        Lum
# Teff1   2.646298  4.856059  3.327704  6.802571  30.664889
# logg1   0.096799  0.142401  0.161107  0.065123   0.628613
# FeH1    0.093454  0.249416  0.160110  0.096472   0.627286
# Vmag    0.265913  0.275419  0.392158  0.114950   1.238871
# e_Vmag  0.051941  0.056784  0.077809  0.021103   0.256724
# Teff2   2.789345  4.935901  3.170948  6.926419  30.814898
# logg2   0.247796  0.092748  0.391458  0.054579   1.384448
# FeH2    0.092748  0.251797  0.159643  0.097517   0.629674
# Rad     0.391458  0.159643  0.637769  0.064567   2.348456
# Mass    0.054579  0.097517  0.064567  0.137566   0.612823
# Lum     1.384448  0.629674  2.348456  0.612823   9.328316

# %%
# Compute covariance matrix
corr_matrix = dfG.select_dtypes(include=['number']).drop(['recno','SubClass'], axis=1).corr()
corr_matrix
# Out:
#            Teff1     logg1      FeH1      Vmag    e_Vmag     Teff2     logg2  \
# Teff1   1.000000 -0.224632  0.279378  0.074274  0.036742  0.979689  0.082214
# logg1  -0.224632  1.000000 -0.593879  0.168832  0.102935 -0.229957  0.279698
# FeH1    0.279378 -0.593879  1.000000 -0.237063 -0.142282  0.272756 -0.140757
# Vmag    0.074274  0.168832 -0.237063  1.000000  0.517658  0.075402  0.223049
# e_Vmag  0.036742  0.102935 -0.142282  0.517658  1.000000  0.036192  0.120552
# Teff2   0.979689 -0.229957  0.272756  0.075402  0.036192  1.000000  0.089971
# logg2   0.082214  0.279698 -0.140757  0.223049  0.120552  0.089971  1.000000
# FeH2    0.272447 -0.595684  0.986666 -0.235481 -0.141792  0.277251 -0.137868
# Rad     0.050511 -0.301030  0.160526 -0.188484 -0.105109  0.045176 -0.969642
# Mass    0.978589 -0.228032  0.270187  0.075080  0.035846  0.999306  0.087386
# Lum     0.293254 -0.313332  0.168462 -0.128607 -0.078230  0.291682 -0.829193
#
#             FeH2       Rad      Mass       Lum
# Teff1   0.272447  0.050511  0.978589  0.293254
# logg1  -0.595684 -0.301030 -0.228032 -0.313332
# FeH1    0.986666  0.160526  0.270187  0.168462
# Vmag   -0.235481 -0.188484  0.075080 -0.128607
# e_Vmag -0.141792 -0.105109  0.035846 -0.078230
# Teff2   0.277251  0.045176  0.999306  0.291682
# logg2  -0.137868 -0.969642  0.087386 -0.829193
# FeH2    1.000000  0.158702  0.274534  0.168802
# Rad     0.158702  1.000000  0.047517  0.927040
# Mass    0.274534  0.047517  1.000000  0.292655
# Lum     0.168802  0.927040  0.292655  1.000000

# %%
# Set style and context for better aesthetics
sns.set_theme(style="white", font_scale=1.2)
plt.figure(figsize=(10, 8))

# Generate a mask for the upper triangle (optional)
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# Create heatmap with custom diverging colormap
heatmap = sns.heatmap(
    corr_matrix,
    mask=mask,  # Hide upper triangle if desired
    annot=True,  # Show correlation values
    fmt=".2f",   # Round to 2 decimals
    cmap="coolwarm",  # Blue (negative) -> Red (positive)
    center=0,    # Center colormap at 0
    square=True,  # Force square cells
    linewidths=0.5,  # Add grid lines
    cbar_kws={"shrink": 0.8},  # Adjust colorbar size
    annot_kws={"size": 12}  # Annotation font size
)

# Improve title and labels
heatmap.set_title("Correlation Matrix", pad=20, fontsize=18)
heatmap.set_xticklabels(heatmap.get_xticklabels(), rotation=45, ha='right')
heatmap.set_yticklabels(heatmap.get_yticklabels(), rotation=0)

# Tight layout to avoid cutoff
plt.tight_layout()
plt.show()

# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import wasserstein_distance, ks_2samp, norm

# Initialize results storage
results = {}

# Quantities with paired measurements (1/2)
paired_quantities = ['Teff', 'logg', 'FeH']
# Quantities without paired measurements
single_quantities = ['Vmag', 'Lum', 'Mass']

def get_mode(data):
    """Calculate mode using KDE for continuous data"""
    kde = stats.gaussian_kde(data)
    x_eval = np.linspace(data.min(), data.max(), 1000)
    return x_eval[np.argmax(kde(x_eval))]

# Analyze paired quantities
for q in paired_quantities:
    data1 = dfG[f'{q}1'].dropna()
    data2 = dfG[f'{q}2'].dropna()
    
    # Calculate modes
    mode1 = get_mode(data1)
    mode2 = get_mode(data2)
    
    # Distribution comparison tests
    ks_stat, ks_p = ks_2samp(data1, data2)
    w_dist = wasserstein_distance(data1, data2)
    
    # Gaussian fit (practical approximation)
    mu1, std1 = norm.fit(data1)
    mu2, std2 = norm.fit(data2)
    
    # Store results
    results[q] = {
        'primary': {
            'mode': mode1,
            'mu': mu1,
            'std': std1,
        },
        'secondary': {
            'mode': mode2,
            'mu': mu2,
            'std': std2,
        },
        'comparison': {
            'ks_statistic': ks_stat,
            'ks_pvalue': ks_p,
            'wasserstein_dist': w_dist,
            'practical_difference': 'Similar ✅' if w_dist < 0.1*data1.std() else 'Different ❌'
        }
    }

# Analyze single quantities
for q in single_quantities:
    data = dfG[q].dropna()
    
    # Calculate mode
    mode = get_mode(data)
    
    # Gaussian fit
    mu, std = norm.fit(data)
    
    # Store results
    results[q] = {
        'mode': mode,
        'mu': mu,
        'std': std,
    }

# Print results
for q in results:
    if q in paired_quantities:
        print(f"\n{q}1:")
        print(f"  Mode: {results[q]['primary']['mode']:.3f}")
        print(f"  Gaussian fit: μ = {results[q]['primary']['mu']:.3f}, σ = {results[q]['primary']['std']:.3f}")
        
        print(f"\n{q}2:")
        print(f"  Mode: {results[q]['secondary']['mode']:.3f}")
        print(f"  Gaussian fit: μ = {results[q]['secondary']['mu']:.3f}, σ = {results[q]['secondary']['std']:.3f}")
        
        print(f"\n  Distribution comparison (1 vs 2):")
        print(f"  KS statistic = {results[q]['comparison']['ks_statistic']:.3f}")
        print(f"  Wasserstein distance = {results[q]['comparison']['wasserstein_dist']:.3f}")
        print(f"  Practical difference: {results[q]['comparison']['practical_difference']}")
        print(f"  (Threshold: {0.1*results[q]['primary']['std']:.3f} = 10% of σ₁)")
    else:
        print(f"\n{q}:")
        print(f"  Mode: {results[q]['mode']:.3f}")
        print(f"  Gaussian fit: μ = {results[q]['mu']:.3f}, σ = {results[q]['std']:.3f}")
# Out:
# Teff1:
#   Mode: 7297.101
#   Gaussian fit: μ = 7361.362, σ = 343.723
#
# Teff2:
#   Mode: 7295.847
#   Gaussian fit: μ = 7358.283, σ = 348.965
#
#   Distribution comparison (1 vs 2):
#   KS statistic = 0.008
#   Wasserstein distance = 4.576
#   Practical difference: Similar ✅
#   (Threshold: 34.372 = 10% of σ₁)
#
# logg1:
#   Mode: 4.051
#   Gaussian fit: μ = 4.037, σ = 0.135
#
# logg2:
#   Mode: 4.188
#   Gaussian fit: μ = 4.088, σ = 0.248
#
#   Distribution comparison (1 vs 2):
#   KS statistic = 0.281
#   Wasserstein distance = 0.114
#   Practical difference: Different ❌
#   (Threshold: 0.014 = 10% of σ₁)
#
# FeH1:
#   Mode: -0.105
#   Gaussian fit: μ = -0.030, σ = 0.250
#
# FeH2:
#   Mode: -0.098
#   Gaussian fit: μ = -0.031, σ = 0.252
#
#   Distribution comparison (1 vs 2):
#   KS statistic = 0.007
#   Wasserstein distance = 0.002
#   Practical difference: Similar ✅
#   (Threshold: 0.025 = 10% of σ₁)
#
# Vmag:
#   Mode: 13.365
#   Gaussian fit: μ = 13.325, σ = 1.279
#
# Lum:
#   Mode: 7.150
#   Gaussian fit: μ = 12.043, σ = 9.328
#
# Mass:
#   Mode: 1.647
#   Gaussian fit: μ = 1.674, σ = 0.138

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(15, 10))

quantities =  paired_quantities + single_quantities
for i, q in enumerate(quantities, 1):
    plt.subplot(3, 2, i)
    if q in paired_quantities:
    
        # Plot histograms
        sns.histplot(dfG[f'{q}1'], color='blue', alpha=0.5, label=f'{q}1', bins=30, stat='density')
        sns.histplot(dfG[f'{q}2'], color='red', alpha=0.5, label=f'{q}2', bins=30, stat='density')
        
        # Plot fitted Gaussians
        x = np.linspace(min(dfG[f'{q}1'].min(), dfG[f'{q}2'].min()), 
                        max(dfG[f'{q}1'].max(), dfG[f'{q}2'].max()), 200)
        
        plt.plot(x, stats.norm.pdf(x, results[q]['primary']['mu'], results[q]['primary']['std']), 
                 color='purple', linestyle='--', linewidth=2)
        plt.plot(x, stats.norm.pdf(x, results[q]['secondary']['mu'], results[q]['secondary']['std']), 
                 color='brown', linestyle='--', linewidth=2)

    else:
        # Plot histograms
        sns.histplot(dfG[f'{q}'], color='blue', alpha=0.5, label=f'{q}1', bins=30, stat='density')
        
        # Plot fitted Gaussians
        x = np.linspace(min(dfG[f'{q}'].min(), dfG[f'{q}'].min()), 
                        max(dfG[f'{q}'].max(), dfG[f'{q}'].max()), 200)
        
        plt.plot(x, stats.norm.pdf(x, results[q]['mu'], results[q]['std']), 
                 'k-', linewidth=2)
        
    
    plt.title(f'{q} Distribution')
    plt.legend()
    plt.xlabel(q)

plt.tight_layout()
plt.show()

# %%
# sns.scatterplot(data=df, x='Teff1', y='Lum', hue='subCl', palette='plasma', size='Rad')
# plt.gca().invert_xaxis()  # HR convention: hot (left) to cool (right)

# %%
sns.jointplot(data=dfG, x='Teff1', y='Teff2', kind='hex', cmap='magma')
sns.jointplot(data=dfG, x='Mass', y='Teff1', kind='hex', cmap='magma')
sns.jointplot(data=dfG, x='Mass', y='Teff2', kind='hex', cmap='magma')

# %%
sns.pairplot(dfG[['Teff1', 'Teff2', 'Mass']], corner=True, plot_kws={'alpha': 0.5})

# %%
sns.pairplot(dfG[['Lum', 'Rad','Mass','logg1','logg2']], corner=True, plot_kws={'alpha': 0.5})
